# %%
from skimage.io import imread
from skimage.transform import resize
import matplotlib.pyplot as plt
import numpy as np

# %%
path='C:/Users/cytor/Desktop/'

# %%
shape=(207,336,4)

# %%
opath=path+'img.png'
oimg=imread(opath)
oshape = np.shape(oimg)
print(oshape)
# Out:
# (595, 1099, 4)

# %%
oimg=resize(oimg,(shape[0],shape[1]))
plt.imshow(oimg)
plt.show()

# %%
# plt.rcParams['savefig.dpi'] = 300 #图片像素
# plt.rcParams['figure.dpi'] = 100 #分辨率
plt.axis('off')
plt.imshow(oimg)
plt.savefig(path+'oimg.png',bbox_inches='tight',pad_inches=0.0)
#,dpi=300
plt.show()
print('图片存好了!')
# Out:
# 图片存好了!
