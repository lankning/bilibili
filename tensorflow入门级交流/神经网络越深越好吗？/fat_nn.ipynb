# %% [markdown]
# # 用神经网络的方法来拟合三角函数的数据

# %% [markdown]
# ## 一、制造数据
# 加入噪声

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

x_data = np.linspace(-10,10,2000,dtype=np.float32)[:, np.newaxis]
y_noise = np.random.normal(0,0.1,x_data.shape)
y_data = np.sin(x_data) + y_noise
print(np.shape(x_data))
plt.plot(x_data,y_data)
plt.show()
# Out:
# (2000, 1)

# %% [markdown]
# ## 二、构建BP神经网络

# %%
def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

#占位
x = tf.placeholder(tf.float32, [None, 1],name='x')
y = tf.placeholder(tf.float32, [None, 1],name='y')
keep_prob = tf.placeholder(tf.float32,name='keep_prob')
#use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
#rate = tf.placeholder(tf.float32,name='rate')

#first fully layer
w_fc1 = weight_variable([1,2048])
b_fc1 = bias_variable([2048])
h_fc1 = tf.nn.relu(tf.nn.bias_add(tf.matmul(x, w_fc1), b_fc1))
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

#second fully layer
w_fc2 = weight_variable([2048,1])
b_fc2 = bias_variable([1])
y_pred = tf.nn.bias_add(tf.matmul(h_fc1_drop, w_fc2), b_fc2,name='y_pred')
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0718 14:58:07.471823 17976 deprecation.py:506] From <ipython-input-2-eee15bbe9aba>:20: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %% [markdown]
# ## 三、定义损失函数和优化器

# %%
loss = tf.reduce_mean(tf.square(y - y_pred))
train_step = tf.compat.v1.train.AdamOptimizer(1e-4).minimize(loss)
real = tf.reshape(y,[-1, 1])
correct_prediction = tf.equal(y_pred,real)
correct_prediction = tf.cast(correct_prediction, tf.float32)
accuracy = tf.reduce_mean(correct_prediction,name='accuracy')

# %% [markdown]
# ## 四、开始运算

# %%
with tf.Session() as sess:
    sess.run(tf.compat.v1.global_variables_initializer())
    step = 1
    train_loss=1
    while step<=10001:
        sess.run(train_step,feed_dict={x: x_data, y: y_data, keep_prob: 0.75})
        if step%100 == 0:
            pred,acc,train_loss = sess.run([y_pred,accuracy,loss],feed_dict={x: x_data, y: y_data, keep_prob: 1.00})
            print ('step:%d,train loss:%f,accuracy:%f' % (step,train_loss,acc))
            plt.plot(x_data,y_data,'b',x_data,pred,'r')
            plt.show()
        step += 1
# Out:
# step:100,train loss:0.427468,accuracy:0.000000
# step:200,train loss:0.386925,accuracy:0.000000
# step:300,train loss:0.355788,accuracy:0.000000
# step:400,train loss:0.330790,accuracy:0.000000
# step:500,train loss:0.311652,accuracy:0.000000
# step:600,train loss:0.295396,accuracy:0.000000
# step:700,train loss:0.282321,accuracy:0.000000
# step:800,train loss:0.272232,accuracy:0.000000
# step:900,train loss:0.263867,accuracy:0.000000
# step:1000,train loss:0.258141,accuracy:0.000000
# step:1100,train loss:0.251665,accuracy:0.000000
# step:1200,train loss:0.247170,accuracy:0.000000
# step:1300,train loss:0.243520,accuracy:0.000000
# step:1400,train loss:0.239966,accuracy:0.000000
# step:1500,train loss:0.237392,accuracy:0.000000
# step:1600,train loss:0.234750,accuracy:0.000000
# step:1700,train loss:0.232730,accuracy:0.000000
# step:1800,train loss:0.230538,accuracy:0.000000
# step:1900,train loss:0.229580,accuracy:0.000000
# step:2000,train loss:0.227978,accuracy:0.000000
# step:2100,train loss:0.226784,accuracy:0.000000
# step:2200,train loss:0.225361,accuracy:0.000000
# step:2300,train loss:0.224833,accuracy:0.000000
# step:2400,train loss:0.224486,accuracy:0.000000
# step:2500,train loss:0.223781,accuracy:0.000000
# step:2600,train loss:0.223800,accuracy:0.000000
# step:2700,train loss:0.223674,accuracy:0.000000
# step:2800,train loss:0.223183,accuracy:0.000000
# step:2900,train loss:0.223079,accuracy:0.000000
# step:3000,train loss:0.222841,accuracy:0.000000
# step:3100,train loss:0.222630,accuracy:0.000000
# step:3200,train loss:0.222627,accuracy:0.000000
# step:3300,train loss:0.222511,accuracy:0.000000
# step:3400,train loss:0.222492,accuracy:0.000000
# step:3500,train loss:0.222612,accuracy:0.000000
# step:3600,train loss:0.222471,accuracy:0.000000
# step:3700,train loss:0.222554,accuracy:0.000000
# step:3800,train loss:0.222770,accuracy:0.000000
# step:3900,train loss:0.222645,accuracy:0.000000
# step:4000,train loss:0.222560,accuracy:0.000000
# step:4100,train loss:0.222570,accuracy:0.000000
# step:4200,train loss:0.222806,accuracy:0.000000
# step:4300,train loss:0.222585,accuracy:0.000000
# step:4400,train loss:0.222612,accuracy:0.000000
# step:4500,train loss:0.222944,accuracy:0.000000
# step:4600,train loss:0.222970,accuracy:0.000000
# step:4700,train loss:0.222661,accuracy:0.000000
# step:4800,train loss:0.222385,accuracy:0.000000
# step:4900,train loss:0.222171,accuracy:0.000000
# step:5000,train loss:0.222052,accuracy:0.000000
# step:5100,train loss:0.221820,accuracy:0.000000
# step:5200,train loss:0.221270,accuracy:0.000000
# step:5300,train loss:0.220863,accuracy:0.000000
# step:5400,train loss:0.220588,accuracy:0.000000
# step:5500,train loss:0.219969,accuracy:0.000000
# step:5600,train loss:0.219573,accuracy:0.000000
# step:5700,train loss:0.219105,accuracy:0.000000
# step:5800,train loss:0.218531,accuracy:0.000000
# step:5900,train loss:0.217920,accuracy:0.000000
# step:6000,train loss:0.217426,accuracy:0.000000
# step:6100,train loss:0.217056,accuracy:0.000000
# step:6200,train loss:0.217071,accuracy:0.000000
# step:6300,train loss:0.216073,accuracy:0.000000
# step:6400,train loss:0.215179,accuracy:0.000000
# step:6500,train loss:0.215175,accuracy:0.000000
# step:6600,train loss:0.214077,accuracy:0.000000
# step:6700,train loss:0.213537,accuracy:0.000000
# step:6800,train loss:0.212918,accuracy:0.000000
# step:6900,train loss:0.212475,accuracy:0.000000
# step:7000,train loss:0.211781,accuracy:0.000000
# step:7100,train loss:0.211081,accuracy:0.000000
# step:7200,train loss:0.210693,accuracy:0.000000
# step:7300,train loss:0.209944,accuracy:0.000000
# step:7400,train loss:0.209480,accuracy:0.000000
# step:7500,train loss:0.208919,accuracy:0.000000
# step:7600,train loss:0.208725,accuracy:0.000000
# step:7700,train loss:0.208457,accuracy:0.000000
# step:7800,train loss:0.207633,accuracy:0.000000
# step:7900,train loss:0.207371,accuracy:0.000000
# step:8000,train loss:0.206786,accuracy:0.000000
# step:8100,train loss:0.206460,accuracy:0.000000
# step:8200,train loss:0.206095,accuracy:0.000000
# step:8300,train loss:0.206098,accuracy:0.000000
# step:8400,train loss:0.205660,accuracy:0.000000
# step:8500,train loss:0.205193,accuracy:0.000000
# step:8600,train loss:0.204999,accuracy:0.000000
# step:8700,train loss:0.204630,accuracy:0.000000
# step:8800,train loss:0.204593,accuracy:0.000000
# step:8900,train loss:0.204462,accuracy:0.000000
# step:9000,train loss:0.204173,accuracy:0.000000
# step:9100,train loss:0.204375,accuracy:0.000000
# step:9200,train loss:0.203747,accuracy:0.000000
# step:9300,train loss:0.203714,accuracy:0.000000
# step:9400,train loss:0.203215,accuracy:0.000000
# step:9500,train loss:0.203870,accuracy:0.000000
# step:9600,train loss:0.202899,accuracy:0.000000
# step:9700,train loss:0.203374,accuracy:0.000000
# step:9800,train loss:0.202751,accuracy:0.000000
# step:9900,train loss:0.202631,accuracy:0.000000
# step:10000,train loss:0.202495,accuracy:0.000000
